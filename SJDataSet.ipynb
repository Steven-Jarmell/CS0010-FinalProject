# %%
import pandas as pd
# %matplotlib inline

data = pd.read_csv("airQuality.csv")

df = data[['site', 'so2']].groupby(by='site')
df1 = data[['site', 'pm25t']].groupby(by='site')
df2 = data[['site', 'ozone']].groupby(by='site')

#df.sum().plot(kind = 'bar', figsize=(15,10))
#Include particulate matter and ozone and overlay values on graph
#Do query mask to get only values from 2020-2021 to show more recent data

# %%
df.sum().plot(kind = 'bar', figsize=(15,10))
df1.sum().plot(kind = 'bar', figsize=(15,10))
df2.sum().plot(kind = 'bar', figsize=(15,10))
