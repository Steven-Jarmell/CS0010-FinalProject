# %%
import pandas as pd
# %matplotlib inline

data = pd.read_csv("airQuality.csv")
df = data[['site', 'so2']]
df1 = df['site'].value_counts()

df1.plot(x="Locations", y="SO2 Levels",figsize=(15,10), kind = 'bar',color="Blue")
#Not sure why axis titles wont pop up, researched it, might be jupyterlab
#Why are the values for most of the locations all the same?
